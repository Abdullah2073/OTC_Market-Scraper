# %%
#Importing the necessary libraries
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import UnexpectedAlertPresentException, NoAlertPresentException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.action_chains import ActionChains

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
url = "https://www.otcmarkets.com/"
driver.get(url)

# %%
Accept_Cookies = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[2]/div[2]/div[1]/div/div/div[2]/button")
Accept_Cookies.click()

# %%
Stock_Screener = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[2]/div[1]/div[2]/a")
Stock_Screener.click()

# %%
time.sleep(5)  # Adjust the sleep time as needed

# Get the current window handle
original_window = driver.current_window_handle

# Get all window handles
all_windows = driver.window_handles

# Switch to the new window (assuming it is the second window)
for window in all_windows:
    if window != original_window:
        driver.switch_to.window(window)
        break

Second_Window = driver.current_window_handle
rows = driver.find_elements(By.XPATH, '/html/body/div/div/div[4]/div/div[1]/table/tbody/tr')
j = 0

# %%
Company_Data = {
    "Company Symbol": [],
    "Market Cap": [],
    "Authorized Shares": [],
    "Outstanding Shares": [],
    "Par Value": [],
    "SEC Filings": [],
    "Address":[],
    "Website": [],
    "Phone": [],
    "Email": [],
    "Audited Financials": [],
    "Latest Report": [],
    "Fiscal Year End" : [],
    "Company Officers": [],
    "BOARD OF DIRECTORS": [],
    "Employees": []
}

# %%
for i in range(0,16):
    counter = 0
    for i in range(len(rows)):
        counter += 1
        print(f"Total Rows: {len(rows)}")
        # Construct the XPath for the link in the first column of the current row
        xpath = f'/html/body/div/div/div[4]/div/div[1]/table/tbody/tr[{i+1}]/td[1]/a'

        # Find the link using the constructed XPath
        link = driver.find_element(By.XPATH, xpath)

        # Click the link
        link.click()
        time.sleep(2)

        # Get all window handles again
        all_windows = driver.window_handles

        # Switch to the new window (assuming it is the third window)

        for window in all_windows:
            if window != original_window and window != Second_Window:
                driver.switch_to.window(window)
                break

           # Extract data from the new page
        try:
            time.sleep(2)
            company_symbol = driver.find_element(By.CLASS_NAME, 'CompanyQuotePage__companySymbol___2D4Xg').text
        except UnexpectedAlertPresentException:
            while True:
                try:
                    alert = driver.switch_to.alert
                    alert.accept()
                    time.sleep(2)  # Wait before checking again
                except NoAlertPresentException:
                    break
            company_symbol = driver.find_element(By.CLASS_NAME, 'CompanyQuotePage__companySymbol___2D4Xg').text

        time.sleep(1)  # Give a slight delay

        try:
            driver.execute_script("window.scrollBy(0, 300);")
            time.sleep(2)
        except UnexpectedAlertPresentException:
            while True:
                try:
                    alert = driver.switch_to.alert
                    alert.accept()
                    time.sleep(2)  # Wait before checking again
                except NoAlertPresentException:
                    break
            driver.execute_script("window.scrollBy(0, 300);")

        time.sleep(2)  # Wait for the page to load

        try:
            security_details = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[1]/div/div[5]/a')
        except UnexpectedAlertPresentException:
            while True:
                try:
                    alert = driver.switch_to.alert
                    alert.accept()
                    time.sleep(2)  # Wait before checking again
                except NoAlertPresentException:
                    break

        security_details = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[1]/div/div[5]/a')
        security_details.click()
        driver.execute_script("window.scrollBy(0, 600);")
        time.sleep(2)  # Wait for the page to load

        market_cap = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/div/div[2]/div[2]').text
        authorized_shares = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/div/div[3]/div[2]').text
        outstanding_shares = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/div/div[4]/div[2]').text
        par_value = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/div/div[9]/div[2]').text

        if market_cap == "Not Available":
            market_cap = "NaN"
        if authorized_shares == "Not Available":
            authorized_shares = "NaN"
        if outstanding_shares == "Not Available":
            outstanding_shares = "NaN" 
        if par_value == "Not Available" or par_value == "No Par Value":
            par_value = "NaN"

        print(market_cap)
        print(authorized_shares)
        print(outstanding_shares)
        print(par_value)

        driver.execute_script("window.scrollBy(0, -300);")
        time.sleep(1)  # Wait for the page to load

        Disclosure = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[1]/div/div[8]/a')
        Disclosure.click()

        driver.execute_script("window.scrollBy(0, 900);")
        time.sleep(1)  # Wait for the page to load

        sec_filings = "NaN"
        try:
            # Attempt to find and retrieve the element
            sec_filings = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/div/div[5]/div/div[1]/table/tbody/tr[1]/td[3]/span/span').text
        except NoSuchElementException:
            # If the element is not found, fill with "Nan"
            sec_filings = "NaN"

        print(sec_filings)

        time.sleep(1)
        driver.execute_script("window.scrollBy(0, -600);")
        time.sleep(1)  # Wait for the page to load

        Company_Profile = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[1]/div/div[4]/a')
        Company_Profile.click()

        driver.execute_script("window.scrollBy(0, 600);")
        time.sleep(1)  # Wait for the page to load

        # Getting Address
        # Find the main div containing the company info
        main_div = driver.find_element(By.CLASS_NAME, "CompanyQuoteProfile__companyInfo___2zvyM")

        # Find all <p> tags within the main div, excluding those after the specified div
        address_p_tags = main_div.find_elements(By.XPATH, "./p[following-sibling::div[contains(@class, 'CompanyQuoteProfile__socialButtons___2Ch7j')]]")

        # Initialize an empty list to store the address lines
        address_lines = []

        # Extract the text from each <p> tag and append it to the address_lines list
        for p_tag in address_p_tags:
            address_lines.append(p_tag.text)

        # Join the address lines into a single string
        address = " ".join(address_lines)
        if not address:
            address = "NaN"

        print(address)

        # Locate the sub div containing website, phone number, and email
        try:
            contact_div = main_div.find_element(By.XPATH, ".//div[@class='styles__default___3EC_N styles__outline___35742 styles__section2___3xacj']")
        except NoSuchElementException:
            contact_div = None

        # Extract the website, phone number, and email
        if contact_div:
            try:
                website = contact_div.find_element(By.XPATH, ".//a[1]").text
            except NoSuchElementException:
                website = "NaN"

            try:
                phone = contact_div.find_element(By.XPATH, ".//p").text
            except NoSuchElementException:
                phone  = "NaN"

            try:
                email = contact_div.find_element(By.XPATH, ".//a[2]").text
            except NoSuchElementException:
                email = "NaN"
        else:
            website = phone = email = "NaN"

        print(website)
        print(phone)
        print(email)

        # Initialize variables to store the extracted texts
        audited_financials, latest_report, fiscal_year_end = "NaN", "NaN", "NaN"

        # Loop through the indices
        main_div = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/div/div[2]/div[3]')

        # Locate the sub divs within the main div
        sub_divs = main_div.find_elements(By.CLASS_NAME, "sc-htpNat.jtWIOA.sc-bdVaJa.gRrvFh")

        for sub_div in sub_divs:
            # Locate the first sub div by class name
            first_div = sub_div.find_element(By.CLASS_NAME, "sc-bdVaJa.jaTTAC")
            # Locate the second sub div by class name
            second_div = sub_div.find_element(By.CLASS_NAME, "styles__firstColumn___383TU.sc-bdVaJa.iHZvIS")

            # Extract text from both divs
            if first_div.text == "Audited Financials":
                if second_div.text == "Not Available":
                    audited_financials = "NaN"
                else:
                    audited_financials = second_div.text
            if first_div.text == "Latest Report":
                if second_div.text == "Not Available":
                    latest_report = "NaN"
                else:
                    latest_report = second_div.text
            if first_div.text == "Fiscal Year End":
                if second_div.text == "Not Available":
                    fiscal_year_end = "NaN"
                else:
                    fiscal_year_end = second_div.text

        # Print the texts in the desired order

        print (audited_financials)
        print (latest_report)
        print (fiscal_year_end)

        main_div_xpath = '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/div/div[3]'
        main_div = driver.find_element(By.XPATH, main_div_xpath)

        # Find all relevant child divs within the main div
        child_divs = main_div.find_elements(By.CLASS_NAME, "styles__item___B9e-1.styles__compact___36meA")

        # List to store the extracted text pairs
        extracted_data = []

        # Iterate through the child divs
        for child_div in child_divs:
            try:
                # Get the text from the first div (with class "sc-bdVaJa jaTTAC")
                first_div_text = child_div.find_element(By.CLASS_NAME, "sc-bdVaJa.jaTTAC").find_element(By.TAG_NAME, "b").text

                # Get the text from the second div (with class "styles__firstColumn___383TU sc-bdVaJa iHZvIS")
                second_div_text = child_div.find_element(By.CLASS_NAME, "styles__item___12taM.sc-htpNat.jtWIOA.sc-bdVaJa.ensNgD").find_element(By.CLASS_NAME, "styles__firstColumn___383TU.sc-bdVaJa.iHZvIS").text

                # Append the text pair to the list
                extracted_data.append(f"{first_div_text} ({second_div_text})")
            except Exception:
                continue

        # Join all texts with commas
        company_officers = ', '.join(extracted_data)
        if company_officers == "":
            company_officers = "NaN"

        # Print or use the company_officers variable
        print(company_officers)


        main_div_xpath1 = '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/div/div[4]/div[3]'
        main_div1 = driver.find_element(By.XPATH, main_div_xpath1)

        # Find all relevant child divs within the main div
        child_divs1 = main_div1.find_elements(By.CLASS_NAME, "styles__item___B9e-1.styles__compact___36meA")

        # Initialize an empty list to store the text
        texts = []

        # Iterate through each child div to find the sub div elements and get their text
        for child_div1 in child_divs1:
            try:
                # Get the text from the first div (with class "sc-bdVaJa jaTTAC")
                first_div_text1 = child_div1.find_element(By.CLASS_NAME, "sc-bdVaJa.jaTTAC").find_element(By.TAG_NAME, "b").text

                # Append the text pair to the list
                texts.append(first_div_text1)
            except Exception:
                continue

        # Join all texts with commas
        board_of_directors = ', '.join(texts)
        if board_of_directors == "":
            board_of_directors = "NaN"
        print(board_of_directors)

        driver.execute_script("window.scrollBy(0, 500);")
        time.sleep(2)  # Wait for the page to load
        try:
            employees = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[2]/div[2]/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/div/div[7]/div[3]/div[3]/div[1]/div/div[2]/div').text
            if employees == "Not Available":
                employees = "NaN"
        except:
            employees = "Nan"
        print(employees)
        # Append the data to the dictionary   

        Company_Data["Company Symbol"].append(company_symbol)
        Company_Data["Market Cap"].append(market_cap)
        Company_Data["Authorized Shares"].append(authorized_shares)
        Company_Data["Outstanding Shares"].append(outstanding_shares)
        Company_Data["Par Value"].append(par_value)
        Company_Data["SEC Filings"].append(sec_filings)
        Company_Data["Address"].append(address)
        Company_Data["Website"].append(website)
        Company_Data["Phone"].append(phone)
        Company_Data["Email"].append(email)
        Company_Data["Audited Financials"].append(audited_financials)
        Company_Data["Latest Report"].append(latest_report)
        Company_Data["Fiscal Year End"].append(fiscal_year_end)
        Company_Data["Company Officers"].append(company_officers)
        Company_Data["BOARD OF DIRECTORS"].append(board_of_directors)
        Company_Data["Employees"].append(employees)

        # Close the WebDriver
        driver.close()
        driver.switch_to.window(Second_Window)
        if j == 350:
            break
        time.sleep(5)
        print(f"Value of counter : {counter}")
        if counter == 20:
            counter = 0
            j += 1
            try:
                driver.find_element(By.XPATH, "/html/body/div/div/div[4]/div/div[2]/div[2]/div/ul/li[12]/a").click()

            except NoSuchWindowException:
                 driver.find_element(By.XPATH, "/html/body/div/div/div[4]/div/div[2]/div[2]/div/ul/li[12]/a/span").click()

            time.sleep(5)
            driver.execute_script("window.scrollBy(0, -1100);")
            time.sleep(2)  # Wait for the page to load
            rows = driver.find_elements(By.XPATH, '/html/body/div/div/div[4]/div/div[1]/table/tbody/tr')
# Out:
# Total Rows: 20
# 41,653,844
# 30,000,000
# 1,939,192
# NaN
# NaN
# 402 G Street Eureka, CA 95501
# www.redwoodcapitalbank.com
# 707-444-9800
# jdalby@rdwo.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), Fiscal Year End (12/31)
# John Dalby, Renee Byers, Cindy Conn, Tammy Brown, Jennifer Budwig, Mary Smith
# Nan
# Value of counter : 1
# Total Rows: 20
# 92,757,954
# 25,000,000
# 7,603,111
# 1.00
# NaN
# 630 29th Ave N. Myrtle Beach, SC 29577
# www.southatlantic.bank
# 843-839-0100
# investorrelations@southatlantic.bank
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), CIK (0001405292), Fiscal Year End (12/31)
# Wayne Wicker, R. Scott Plyler, Matthew H Hobert, Elizabeth W Branham
# Nan
# Value of counter : 2
# Total Rows: 20
# 291,081,813
# 30,000,000
# 8,437,154
# NaN
# NaN
# 75 River Street Santa Cruz, CA 95060
# www.sccountybank.com
# +1 831-457-5000
# info@sccountybank.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), Fiscal Year End (12/31)
# Krista Snelling, Shamara Vandervoort, Cecilia Situ, Frederick L. Caiocca, Jaime Manriquez, Maxwell Sinclair, Shawn Lipman, Angelo DeBernardo, Jr., Tracy Ruelas-Hashimoto, Jon P. Sisk, Mary Anne Carson
# Nan
# Value of counter : 3
# Total Rows: 20
# 57,699,341
# 25,000,000
# 5,629,204
# NaN
# NaN
# 101 Jacksonville Circle P O Box 215 Floyd, VA 24091
# www.skylinenationalbank.bank
# +1 540-745-4191
# ourbest@skylinenationalbank.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: SEC Reporting), Audited Financials (Audited), Latest Report (03/31/2024), CIK (0001657642), Fiscal Year End (12/31)
# Blake M. Edwards, Rodney R. Halsey, Lori Vaught, Beth Worrell, Jonathan L. Kruckow, Shane Osborne
# Nan
# Value of counter : 4
# Total Rows: 20
# 22,461,953
# 20,000,000
# 2,191,410
# 0.01
# NaN
# 8700 Perry Highway Pittsburgh, PA 15237
# www.ssbpgh.com
# +1 412-837-6955
# info@ssbpgh.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Call Report), CIK (0001716188), Fiscal Year End (12/31)
# Joseph Daniel Moon IV, Benjamin Contrucci, Frances Amorose
# Nan
# Value of counter : 5
# Total Rows: 20
# 34,654,300
# 9,000,000
# 2,152,441
# 1.00
# NaN
# 113-125 East Chicago Road P.O. Box 600 Sturgis, MI 49091
# www.sturgis.bank
# +1 269-651-9345
# info@sturgis.bank
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), CIK (0001166362), Fiscal Year End (12/31)
# Jason G Hyska, Matthew D Scheske, Brian P. Hoggatt, Tracey Parker
# Nan
# Value of counter : 6
# Total Rows: 20
# 42,194,306
# 2,000,000
# 1,095,956
# NaN
# NaN
# 1500 Main Street Jasper, IN 47546
# www.svbt.bank
# +1 812-634-1010
# svbt@svbt.bank
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Call Report), Fiscal Year End (12/31)
# Jamie R. Shinabarger, Jeffrey Craig Buse, Ryan Heim, Martin Kaiser, Dianna Land, Ayla McIntire, Sandra Ferrell
# Nan
# Value of counter : 7
# Total Rows: 20
# 13,675,248
# 10,000,000
# 2,333,660
# 0.01
# NaN
# 1938 E. Lincoln Hwy, Unit 201 New Lenox, IL 60451
# www.towncenterbank.com
# +1 815-806-7015
# d.regan@towncenterbank.net
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), Fiscal Year End (12/31)
# Michael Perry, Daniel Regan
# Nan
# Value of counter : 8
# Total Rows: 20
# 63,224,250
# 10,000,000
# 2,107,475
# 1.00
# NaN
# 222 N. Main St. P.O. Box 728 Burlington, IA 52601
# www.tworiversfinancialgroup.com
# +1 319-753-9145
# contactus@tworivers.bank
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), CIK (0001329129), Fiscal Year End (12/31)
# Frank J. Delaney, Andrea Gerst, Rhonda Carlston, Darrell Burchfield
# Nan
# Value of counter : 9
# Total Rows: 20
# 134,340,360
# 10,000,000
# 2,741,640
# 1.00
# NaN
# 24 North Main Street Berlin, MD 21811
# www.taylorbank.com
# +1 410-641-1700
# taylor@taylorbank.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), CIK (0001003986), Fiscal Year End (12/31)
# Raymond M. Thompson, M. Dean Lewis, Tina Kolarik, Douglass M Cook
# Nan
# Value of counter : 10
# Total Rows: 20
# 96,759,120
# 5,000,000
# 2,418,978
# 1.00
# NaN
# 706 Washington St. Mendota, IL 61342
# www.firststatebank.biz
# +1 815-538-2265
# info@firststatebank.biz
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), CIK (0000801901), Fiscal Year End (12/31)
# Timothy J. McConville, Lana Eddy, Kirk Ross, Cory Biers, Jill V Summerhill, Jan Phalen, Jordan Carpenter, Grant Goltz
# Nan
# Value of counter : 11
# Total Rows: 20
# 173,855,136
# 5,000,000
# 3,548,064
# 0.01
# NaN
# 200 East Nashville Avenue Atmore, AL 36502
# www.unitedbank.com
# +1 251-446-6000
# tina.brooks@unitedbank.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), CIK (0000704561), Fiscal Year End (12/31)
# Mike Vincent, Leigh Anne Russell-Jones, Tina Brooks, Brooke Marsh, Carol R Hardy
# Nan
# Value of counter : 12
# Total Rows: 20
# 54,873,030
# 10,000,000
# 2,980,610
# 1.00
# NaN
# 105 Progressive Drive Columbus Grove, OH 45830
# www.theubank.com
# +1 (419) 659-2141
# communicationscenter@theubank.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), CIK (0001087456), Fiscal Year End (12/31)
# Brian D. Young, Klint D. Manz
# Nan
# Value of counter : 13
# Total Rows: 20
# 31,216,500
# 100,000,000
# 5,476,579
# NaN
# NaN
# 19315 Highway 99 Lynnwood, WA 98036
# www.unibankusa.com
# +1 425-275-9700
# simon.bai@unibankusa.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (12/31/2023 Annual Report), Fiscal Year End (12/31)
# Alisa Na, Ellis Chang, Simon Bai, Stephanie Yoon, Sue Suk
# Nan
# Value of counter : 14
# Total Rows: 20
# 52,698,800
# 50,000,000
# 16,520,000
# 1.00
# NaN
# 9866 Garden Grove Blvd. Garden Grove, CA 92844
# www.usmetrobank.com
# 714-620-8888
# jeremyjohnson@usmetrobank.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), Fiscal Year End (12/31)
# Dong Il Kim, Jeremy Alan Johnson, Monique Nguyen, Johann Minkyun You
# Nan
# Value of counter : 15
# Total Rows: 20
# 54,926,629
# 20,000,000
# 7,087,307
# 1.25
# NaN
# 132 North First Street Albemarle, NC 28001
# www.uwharrie.com
# +1 704-982-4415
# investorrelations@uwharrie.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: SEC Reporting), Audited Financials (Audited), Latest Report (03/31/2024), CIK (0000898171), Fiscal Year End (12/31)
# Roger Lee Dick, Jason Robert Andrew, Heather Hunt Almond, Tamara McSwain Singletary, Lisa E. Hartsell, Christy D. Stoner, R. David Beaver, III, Brooke Laton Senter, Keisha Boyce
# Nan
# Value of counter : 16
# Total Rows: 20
# 19,713,620
# 10,000,000
# 1,971,362
# 1.00
# NaN
# 548 N. Lewis Rd Limerick, PA 19468
# www.victorybank.com
# +1 610-948-9000
# VTYB@victorybank.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), Fiscal Year End (12/31)
# Joseph W Major, Robert H. Schultz, Alexander S Kroll, Owen Magers
# Nan
# Value of counter : 17
# Total Rows: 20
# 28,747,714
# 14,000,000
# 1,922,924
# 0.01
# NaN
# 976 South Shannon Street Van Wert, OH 45891
# www.vanwertfederal.com
# +1 4192389662
# customersupport@vanwertfederal.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: SEC Reporting), Audited Financials (Audited), Latest Report (03/31/2024), CIK (0001913838), Fiscal Year End (6/30)
# Michael D. Cahill, Richard Wayne Brackin, CPA, Andrew D. Holy
# Nan
# Value of counter : 18
# Total Rows: 20
# 66,860,020
# 9,000,000
# 1,217,851
# 0.01
# NaN
# 3878 N. Crossover Rd., Suite 20 Fayetteville, AR 72703
# www.signature.bank
# 479-684-3878
# Edward.Riendeau@mail.signature.bank
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), Fiscal Year End (12/31)
# Gary Russell Head, David Brantley Ward, Alexandria Gladden, Edward Pierre Riendeau, Crandall Streett, Tammie Neal, Daniel Joseph Lewis, Jeffrey James Maland, James Scott Sandlin
# Nan
# Value of counter : 19
# Total Rows: 20
# 23,031,113
# 10,000,000
# 1,894,006
# 0.01
# NaN
# 9001 Perry Highway Pittsburgh, PA 15237
# www.wvsbank.com
# +1 412-364-1911
# accounting@wvsbank.com
# NaN
# NaN
# NaN
# Reporting Status (U.S. Reporting: Bank/Thrift), Audited Financials (Audited), Latest Report (03/31/2024 Quarterly Report), CIK (0000910679), Fiscal Year End (6/30)
# David J. Bursic, Michael R Rutan, James M. Hein
# Nan
# Value of counter : 20
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[42], line 306
#     305 try:
# --> 306     driver.find_element(By.XPATH, "/html/body/div/div/div[4]/div/div[2]/div[2]/div/ul/li[12]/a").click()
#     308 except NoSuchWindowException:
#
# File F:\Anaconda\Lib\site-packages\selenium\webdriver\remote\webdriver.py:738, in WebDriver.find_element(self, by, value)
#     736     value = f'[name="{value}"]'
# --> 738 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File F:\Anaconda\Lib\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#
# File F:\Anaconda\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div/div/div[4]/div/div[2]/div[2]/div/ul/li[12]/a"}
#   (Session info: chrome=126.0.6478.63); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00730ED3+27667]
# 	(No symbol) [0x006C6BD4]
# 	(No symbol) [0x005C1AFF]
# 	(No symbol) [0x00602BFE]
# 	(No symbol) [0x00602CDB]
# 	(No symbol) [0x0063EC22]
# 	(No symbol) [0x00623974]
# 	(No symbol) [0x0063CAC7]
# 	(No symbol) [0x006236C6]
# 	(No symbol) [0x005F74D1]
# 	(No symbol) [0x005F804D]
# 	GetHandleVerifier [0x009E3D43+2857603]
# 	GetHandleVerifier [0x00A37EAD+3202029]
# 	GetHandleVerifier [0x007B46D4+566292]
# 	GetHandleVerifier [0x007BB8CC+595468]
# 	(No symbol) [0x006CF9C4]
# 	(No symbol) [0x006CC6D8]
# 	(No symbol) [0x006CC877]
# 	(No symbol) [0x006BE76E]
# 	BaseThreadInitThunk [0x76ADFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77377CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77377C8E+238]
#
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 308
#     305 try:
#     306     driver.find_element(By.XPATH, "/html/body/div/div/div[4]/div/div[2]/div[2]/div/ul/li[12]/a").click()
# --> 308 except NoSuchWindowException:
#     309      driver.find_element(By.XPATH, "/html/body/div/div/div[4]/div/div[2]/div[2]/div/ul/li[12]/a/span").click()
#     311 time.sleep(5)
#
# NameError: name 'NoSuchWindowException' is not defined

# %%
df = pd.DataFrame(Company_Data)
df
# Out:
#    Company Symbol   Market Cap Authorized Shares Outstanding Shares Par Value  \
# 0            RWCB   41,653,844        30,000,000          1,939,192       NaN
# 1            SABK   92,757,954        25,000,000          7,603,111      1.00
# 2            SCZC  291,081,813        30,000,000          8,437,154       NaN
# 3            SLBK   57,699,341        25,000,000          5,629,204       NaN
# 4            SSBP   22,461,953        20,000,000          2,191,410      0.01
# 5            STBI   34,654,300         9,000,000          2,152,441      1.00
# 6            SVBT   42,194,306         2,000,000          1,095,956       NaN
# 7            TCNB   13,675,248        10,000,000          2,333,660      0.01
# 8            TRVR   63,224,250        10,000,000          2,107,475      1.00
# 9            TYCB  134,340,360        10,000,000          2,741,640      1.00
# 10           TYFG   96,759,120         5,000,000          2,418,978      1.00
# 11           UBAB  173,855,136         5,000,000          3,548,064      0.01
# 12           UBOH   54,873,030        10,000,000          2,980,610      1.00
# 13           UNIF   31,216,500       100,000,000          5,476,579       NaN
# 14           USMT   52,698,800        50,000,000         16,520,000      1.00
# 15           UWHR   54,926,629        20,000,000          7,087,307      1.25
# 16           VTYB   19,713,620        10,000,000          1,971,362      1.00
# 17           VWFB   28,747,714        14,000,000          1,922,924      0.01
# 18           WRIV   66,860,020         9,000,000          1,217,851      0.01
# 19           WVFC   23,031,113        10,000,000          1,894,006      0.01
#
#    SEC Filings                                            Address  \
# 0          NaN                      402 G Street Eureka, CA 95501
# 1          NaN             630 29th Ave N. Myrtle Beach, SC 29577
# 2          NaN               75 River Street Santa Cruz, CA 95060
# 3          NaN  101 Jacksonville Circle P O Box 215 Floyd, VA ...
# 4          NaN            8700 Perry Highway Pittsburgh, PA 15237
# 5          NaN  113-125 East Chicago Road P.O. Box 600 Sturgis...
# 6          NaN                  1500 Main Street Jasper, IN 47546
# 7          NaN  1938 E. Lincoln Hwy, Unit 201 New Lenox, IL 60451
# 8          NaN  222 N. Main St. P.O. Box 728 Burlington, IA 52601
# 9          NaN              24 North Main Street Berlin, MD 21811
# 10         NaN               706 Washington St. Mendota, IL 61342
# 11         NaN         200 East Nashville Avenue Atmore, AL 36502
# 12         NaN     105 Progressive Drive Columbus Grove, OH 45830
# 13         NaN                19315 Highway 99 Lynnwood, WA 98036
# 14         NaN     9866 Garden Grove Blvd. Garden Grove, CA 92844
# 15         NaN         132 North First Street Albemarle, NC 28001
# 16         NaN                 548 N. Lewis Rd Limerick, PA 19468
# 17         NaN        976 South Shannon Street Van Wert, OH 45891
# 18         NaN  3878 N. Crossover Rd., Suite 20 Fayetteville, ...
# 19         NaN            9001 Perry Highway Pittsburgh, PA 15237
#
#                             Website              Phone  \
# 0        www.redwoodcapitalbank.com       707-444-9800
# 1            www.southatlantic.bank       843-839-0100
# 2              www.sccountybank.com    +1 831-457-5000
# 3      www.skylinenationalbank.bank    +1 540-745-4191
# 4                    www.ssbpgh.com    +1 412-837-6955
# 5                  www.sturgis.bank    +1 269-651-9345
# 6                     www.svbt.bank    +1 812-634-1010
# 7            www.towncenterbank.com    +1 815-806-7015
# 8   www.tworiversfinancialgroup.com    +1 319-753-9145
# 9                www.taylorbank.com    +1 410-641-1700
# 10           www.firststatebank.biz    +1 815-538-2265
# 11               www.unitedbank.com    +1 251-446-6000
# 12                 www.theubank.com  +1 (419) 659-2141
# 13               www.unibankusa.com    +1 425-275-9700
# 14              www.usmetrobank.com       714-620-8888
# 15                 www.uwharrie.com    +1 704-982-4415
# 16              www.victorybank.com    +1 610-948-9000
# 17           www.vanwertfederal.com      +1 4192389662
# 18               www.signature.bank       479-684-3878
# 19                  www.wvsbank.com    +1 412-364-1911
#
#                                    Email Audited Financials Latest Report  \
# 0                        jdalby@rdwo.com                NaN           NaN
# 1   investorrelations@southatlantic.bank                NaN           NaN
# 2                  info@sccountybank.com                NaN           NaN
# 3        ourbest@skylinenationalbank.com                NaN           NaN
# 4                        info@ssbpgh.com                NaN           NaN
# 5                      info@sturgis.bank                NaN           NaN
# 6                         svbt@svbt.bank                NaN           NaN
# 7             d.regan@towncenterbank.net                NaN           NaN
# 8               contactus@tworivers.bank                NaN           NaN
# 9                  taylor@taylorbank.com                NaN           NaN
# 10               info@firststatebank.biz                NaN           NaN
# 11            tina.brooks@unitedbank.com                NaN           NaN
# 12     communicationscenter@theubank.com                NaN           NaN
# 13              simon.bai@unibankusa.com                NaN           NaN
# 14         jeremyjohnson@usmetrobank.com                NaN           NaN
# 15        investorrelations@uwharrie.com                NaN           NaN
# 16                  VTYB@victorybank.com                NaN           NaN
# 17    customersupport@vanwertfederal.com                NaN           NaN
# 18   Edward.Riendeau@mail.signature.bank                NaN           NaN
# 19                accounting@wvsbank.com                NaN           NaN
#
#    Fiscal Year End                                   Company Officers  \
# 0              NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 1              NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 2              NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 3              NaN  Reporting Status (U.S. Reporting: SEC Reportin...
# 4              NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 5              NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 6              NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 7              NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 8              NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 9              NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 10             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 11             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 12             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 13             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 14             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 15             NaN  Reporting Status (U.S. Reporting: SEC Reportin...
# 16             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 17             NaN  Reporting Status (U.S. Reporting: SEC Reportin...
# 18             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 19             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
#
#                                    BOARD OF DIRECTORS Employees
# 0   John Dalby, Renee Byers, Cindy Conn, Tammy Bro...       Nan
# 1   Wayne Wicker, R. Scott Plyler, Matthew H Hober...       Nan
# 2   Krista Snelling, Shamara Vandervoort, Cecilia ...       Nan
# 3   Blake M. Edwards, Rodney R. Halsey, Lori Vaugh...       Nan
# 4   Joseph Daniel Moon IV, Benjamin Contrucci, Fra...       Nan
# 5   Jason G Hyska, Matthew D Scheske, Brian P. Hog...       Nan
# 6   Jamie R. Shinabarger, Jeffrey Craig Buse, Ryan...       Nan
# 7                         Michael Perry, Daniel Regan       Nan
# 8   Frank J. Delaney, Andrea Gerst, Rhonda Carlsto...       Nan
# 9   Raymond M. Thompson, M. Dean Lewis, Tina Kolar...       Nan
# 10  Timothy J. McConville, Lana Eddy, Kirk Ross, C...       Nan
# 11  Mike Vincent, Leigh Anne Russell-Jones, Tina B...       Nan
# 12                      Brian D. Young, Klint D. Manz       Nan
# 13  Alisa Na, Ellis Chang, Simon Bai, Stephanie Yo...       Nan
# 14  Dong Il Kim, Jeremy Alan Johnson, Monique Nguy...       Nan
# 15  Roger Lee Dick, Jason Robert Andrew, Heather H...       Nan
# 16  Joseph W Major, Robert H. Schultz, Alexander S...       Nan
# 17  Michael D. Cahill, Richard Wayne Brackin, CPA,...       Nan
# 18  Gary Russell Head, David Brantley Ward, Alexan...       Nan
# 19    David J. Bursic, Michael R Rutan, James M. Hein       Nan

# %%
file = "OTC_Matkets_page701.csv"
#df.to_csv(file, index=False)

# %%
df1 = pd.read_csv(file)
df = pd.concat([df1, df], ignore_index=True)
df
# Out:
#      Company Symbol      Market Cap Authorized Shares Outstanding Shares  \
# 0             SNMYF  13,669,628,828               NaN      1,265,706,373
# 1             SNNAF       3,587,462               NaN        197,113,316
# 2             SNNAQ           2,293        50,000,000         22,926,875
# 3              SNNC         953,951       300,000,000        109,649,538
# 4              SNNF      12,845,532        19,000,000          1,848,278
# ...             ...             ...               ...                ...
# 3193           UWHR      54,926,629        20,000,000          7,087,307
# 3194           VTYB      19,713,620        10,000,000          1,971,362
# 3195           VWFB      28,747,714        14,000,000          1,922,924
# 3196           WRIV      66,860,020         9,000,000          1,217,851
# 3197           WVFC      23,031,113        10,000,000          1,894,006
#
#      Par Value SEC Filings                                            Address  \
# 0          NaN         NaN  Level 23, Heritage Lanes 80 Ann Street Brisban...
# 1          NaN         NaN  2905-700 West Georgia Street Vancouver, BC V7Y...
# 2          NaN         NaN  30699 Russell Ranch Road Suite 140 Westlake Vi...
# 3        0.001         NaN    8657 N Caballo Circle Paradise Valley, AZ 85253
# 4         0.01         NaN           35 Oswego Street Baldwinsville, NY 13027
# ...        ...         ...                                                ...
# 3193      1.25         NaN         132 North First Street Albemarle, NC 28001
# 3194      1.00         NaN                 548 N. Lewis Rd Limerick, PA 19468
# 3195      0.01         NaN        976 South Shannon Street Van Wert, OH 45891
# 3196      0.01         NaN  3878 N. Crossover Rd., Suite 20 Fayetteville, ...
# 3197      0.01         NaN            9001 Perry Highway Pittsburgh, PA 15237
#
#                       Website              Phone  \
# 0     www.suncorpgroup.com.au  +61 617-3362-2222
# 1     www.siennaresources.com    +1 604-646-6900
# 2                         NaN     (818) 629-2256
# 3             www.snncinc.com      +1 4804076445
# 4       www.senecasavings.com      +1 3156380233
# ...                       ...                ...
# 3193         www.uwharrie.com    +1 704-982-4415
# 3194      www.victorybank.com    +1 610-948-9000
# 3195   www.vanwertfederal.com      +1 4192389662
# 3196       www.signature.bank       479-684-3878
# 3197          www.wvsbank.com    +1 412-364-1911
#
#                                     Email Audited Financials  \
# 0       investor.relations@suncorp.com.au            Audited
# 1                info@siennaresources.com            Audited
# 2                                     NaN            Audited
# 3                       david@snncinc.com          Unaudited
# 4                 ehelp@senecasavings.com                NaN
# ...                                   ...                ...
# 3193       investorrelations@uwharrie.com                NaN
# 3194                 VTYB@victorybank.com                NaN
# 3195   customersupport@vanwertfederal.com                NaN
# 3196  Edward.Riendeau@mail.signature.bank                NaN
# 3197               accounting@wvsbank.com                NaN
#
#                             Latest Report Fiscal Year End  \
# 0                                     NaN          Jun-30
# 1     06/30/2005 Interim Financial Report          Dec-31
# 2                              09/30/2019             NaN
# 3             02/29/2024 Quarterly Report          Aug-31
# 4                                     NaN             NaN
# ...                                   ...             ...
# 3193                                  NaN             NaN
# 3194                                  NaN             NaN
# 3195                                  NaN             NaN
# 3196                                  NaN             NaN
# 3197                                  NaN             NaN
#
#                                        Company Officers  \
# 0            Patrick Snowball (CEO), John Nesbitt (CFO)
# 1                           Jason Gigliotti (President)
# 2                                                   NaN
# 3       David Mersky (CEO), Carl Philip Ranno (Counsel)
# 4     Reporting Status (U.S. Reporting: Bank/Thrift)...
# ...                                                 ...
# 3193  Reporting Status (U.S. Reporting: SEC Reportin...
# 3194  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 3195  Reporting Status (U.S. Reporting: SEC Reportin...
# 3196  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 3197  Reporting Status (U.S. Reporting: Bank/Thrift)...
#
#                                      BOARD OF DIRECTORS           Employees
# 0                                                   NaN                 NaN
# 1                          Greame Sewell, Negar Towfigh                 NaN
# 2                                                   NaN                 NaN
# 3                          David Mersky, Booker T Evans  1 as of 06/01/2024
# 4                          Joseph Vitale, Vincent Fazio                 Nan
# ...                                                 ...                 ...
# 3193  Roger Lee Dick, Jason Robert Andrew, Heather H...                 Nan
# 3194  Joseph W Major, Robert H. Schultz, Alexander S...                 Nan
# 3195  Michael D. Cahill, Richard Wayne Brackin, CPA,...                 Nan
# 3196  Gary Russell Head, David Brantley Ward, Alexan...                 Nan
# 3197    David J. Bursic, Michael R Rutan, James M. Hein                 Nan
#
# [3198 rows x 16 columns]

# %%
df.to_csv(file, index=False)

# %%
df2 = pd.read_csv(file)
duplicates = df2[df2.duplicated(subset='Company Symbol', keep=False)]
duplicates
# Out:
#      Company Symbol Market Cap Authorized Shares Outstanding Shares Par Value  \
# 1276           TOGI  2,170,536     2,000,000,000        183,943,705     0.001
# 1277          TOGIW        NaN               NaN                NaN       NaN
# 1278          TOGOF  2,353,462       999,999,999        186,782,706       NaN
# 1279          TOGPF        NaN               NaN                NaN       NaN
# 1280           TOGI  2,170,536     2,000,000,000        183,943,705     0.001
# 1281          TOGIW        NaN               NaN                NaN       NaN
# 1282          TOGOF  2,353,462       999,999,999        186,782,706       NaN
# 1283          TOGPF        NaN               NaN                NaN       NaN
# 2259           VSMR  7,567,898       250,000,000        227,948,748     0.001
# 2261           VSMR  7,567,898       250,000,000        227,948,748     0.001
#
#      SEC Filings                                            Address  \
# 1276  05/29/2024             1421 McCarthy Blvd. Milpitas, CA 95035
# 1277  05/29/2024             1421 McCarthy Blvd. Milpitas, CA 95035
# 1278         NaN  410 St. Nicolas Suite 236 Montreal, QC H2Y 2P5...
# 1279         NaN  15/5 Moo 6 Bangbuathong-Suphanburi Road, Lahar...
# 1280  05/29/2024             1421 McCarthy Blvd. Milpitas, CA 95035
# 1281  05/29/2024             1421 McCarthy Blvd. Milpitas, CA 95035
# 1282         NaN  410 St. Nicolas Suite 236 Montreal, QC H2Y 2P5...
# 1283         NaN  15/5 Moo 6 Bangbuathong-Suphanburi Road, Lahar...
# 2259         NaN                   40 Hillside Ave Mahwah, NJ 07430
# 2261         NaN                   40 Hillside Ave Mahwah, NJ 07430
#
#                        Website             Phone  \
# 1276           turnongreen.com    (510) 657-2635
# 1277           turnongreen.com    (510) 657-2635
# 1278      www.tomagoldcorp.com   +1 514-583-3490
# 1279  www.thaiopticalgroup.com  +66 063 903 0780
# 1280           turnongreen.com    (510) 657-2635
# 1281           turnongreen.com    (510) 657-2635
# 1282      www.tomagoldcorp.com   +1 514-583-3490
# 1283  www.thaiopticalgroup.com  +66 063 903 0780
# 2259       www.verifysmart.net  +1 973- 897-6294
# 2261       www.verifysmart.net  +1 973- 897-6294
#
#                                Email Audited Financials  \
# 1276            info@turnongreen.com            Audited
# 1277            info@turnongreen.com            Audited
# 1278  david.grondin@tomagoldcorp.com            Audited
# 1279         ir@thaiopticalgroup.com            Audited
# 1280            info@turnongreen.com            Audited
# 1281            info@turnongreen.com            Audited
# 1282  david.grondin@tomagoldcorp.com            Audited
# 1283         ir@thaiopticalgroup.com            Audited
# 2259        info@verifysmartcorp.com          Unaudited
# 2261        info@verifysmartcorp.com          Unaudited
#
#                             Latest Report Fiscal Year End  \
# 1276                           03/31/2024          Dec-31
# 1277                           03/31/2024          Dec-31
# 1278  02/29/2024 Interim Financial Report          Aug-31
# 1279                                  NaN          Dec-31
# 1280                           03/31/2024          Dec-31
# 1281                           03/31/2024          Dec-31
# 1282  02/29/2024 Interim Financial Report          Aug-31
# 1283                                  NaN          Dec-31
# 2259          03/31/2024 Quarterly Report          Jun-30
# 2261          03/31/2024 Quarterly Report          Jun-30
#
#                                        Company Officers  \
# 1276  Amos Kohn (CEO), Marcus Charuvastra (President...
# 1277  Amos Kohn (CEO), Marcus Charuvastra (President...
# 1278  David Grondin (CEO), Martin Nicoletti (CFO), T...
# 1279                                                NaN
# 1280  Amos Kohn (CEO), Marcus Charuvastra (President...
# 1281  Amos Kohn (CEO), Marcus Charuvastra (President...
# 1282  David Grondin (CEO), Martin Nicoletti (CFO), T...
# 1283                                                NaN
# 2259  Anthony Cinotti (President, Interim CEO, Inter...
# 2261  Anthony Cinotti (President, Interim CEO, Inter...
#
#                                      BOARD OF DIRECTORS            Employees
# 1276  Amos Kohn, Marcus Charuvastra, Douglas Paul Gintz  20 as of 05/28/2024
# 1277  Amos Kohn, Marcus Charuvastra, Douglas Paul Gintz  20 as of 05/28/2024
# 1278  Wanda Cutler, Jean-Sebastien Jacquetin, Caitli...   2 as of 04/16/2024
# 1279                                                NaN                  NaN
# 1280  Amos Kohn, Marcus Charuvastra, Douglas Paul Gintz  20 as of 05/28/2024
# 1281  Amos Kohn, Marcus Charuvastra, Douglas Paul Gintz  20 as of 05/28/2024
# 1282  Wanda Cutler, Jean-Sebastien Jacquetin, Caitli...   2 as of 04/16/2024
# 1283                                                NaN                  NaN
# 2259  Greg Barna, Anthony Cinotti, Jay Gentry, Stewa...   5 as of 12/31/2023
# 2261  Greg Barna, Anthony Cinotti, Jay Gentry, Stewa...   5 as of 12/31/2023

# %%
df_cleaned = df2.drop_duplicates(subset='Company Symbol', keep=False)
df_cleaned
# Out:
#      Company Symbol      Market Cap Authorized Shares Outstanding Shares  \
# 0             SNMYF  13,669,628,828               NaN      1,265,706,373
# 1             SNNAF       3,587,462               NaN        197,113,316
# 2             SNNAQ           2,293        50,000,000         22,926,875
# 3              SNNC         953,951       300,000,000        109,649,538
# 4              SNNF      12,845,532        19,000,000          1,848,278
# ...             ...             ...               ...                ...
# 2296          VTRNF             NaN               NaN          8,057,000
# 2297          VTSCF   3,318,957,784               NaN         40,021,196
# 2298          VTSCY   2,827,497,497               NaN         40,021,196
# 2299          VTSYF     830,180,429               NaN      1,020,881,000
# 2300          VTSYY             NaN               NaN                NaN
#
#      Par Value SEC Filings                                            Address  \
# 0          NaN         NaN  Level 23, Heritage Lanes 80 Ann Street Brisban...
# 1          NaN         NaN  2905-700 West Georgia Street Vancouver, BC V7Y...
# 2          NaN         NaN  30699 Russell Ranch Road Suite 140 Westlake Vi...
# 3        0.001         NaN    8657 N Caballo Circle Paradise Valley, AZ 85253
# 4         0.01         NaN           35 Oswego Street Baldwinsville, NY 13027
# ...        ...         ...                                                ...
# 2296       NaN         NaN          Willy-Brandt-Weg 41 Munster 48155 Germany
# 2297       NaN         NaN         Siemensstrasse 12 Regensburg 93055 Germany
# 2298       NaN         NaN         Siemensstrasse 12 Regensburg 93055 Germany
# 2299       NaN         NaN  1 Kin Wong Street, Tuen Mun The New Territorie...
# 2300       NaN         NaN  1 Kin Wong Street, Tuen Mun The New Territorie...
#
#                               Website                Phone  \
# 0             www.suncorpgroup.com.au    +61 617-3362-2222
# 1             www.siennaresources.com      +1 604-646-6900
# 2                                 NaN       (818) 629-2256
# 3                     www.snncinc.com        +1 4804076445
# 4               www.senecasavings.com        +1 3156380233
# ...                               ...                  ...
# 2296       www.vectron-systems.com/en      +49 251 2856150
# 2297  www.vitesco-technologies.com/en  +49 941 203 190 330
# 2298  www.vitesco-technologies.com/en  +49 941 203 190 330
# 2299                  www.vitasoy.com    011-852-2466-0333
# 2300                  www.vitasoy.com    011-852-2466-0333
#
#                                   Email Audited Financials  \
# 0     investor.relations@suncorp.com.au            Audited
# 1              info@siennaresources.com            Audited
# 2                                   NaN            Audited
# 3                     david@snncinc.com          Unaudited
# 4               ehelp@senecasavings.com                NaN
# ...                                 ...                ...
# 2296                    info@vectron.de                NaN
# 2297             heiko.eber@vitesco.com                NaN
# 2298             heiko.eber@vitesco.com                NaN
# 2299                   info@vitasoy.com            Audited
# 2300                   info@vitasoy.com            Audited
#
#                             Latest Report Fiscal Year End  \
# 0                                     NaN          Jun-30
# 1     06/30/2005 Interim Financial Report          Dec-31
# 2                              09/30/2019             NaN
# 3             02/29/2024 Quarterly Report          Aug-31
# 4                                     NaN             NaN
# ...                                   ...             ...
# 2296                                  NaN          Dec-31
# 2297                                  NaN          Dec-31
# 2298                                  NaN          Dec-31
# 2299                                  NaN          Dec-31
# 2300                                  NaN          Dec-31
#
#                                        Company Officers  \
# 0            Patrick Snowball (CEO), John Nesbitt (CFO)
# 1                           Jason Gigliotti (President)
# 2                                                   NaN
# 3       David Mersky (CEO), Carl Philip Ranno (Counsel)
# 4     Reporting Status (U.S. Reporting: Bank/Thrift)...
# ...                                                 ...
# 2296                                                NaN
# 2297                                                NaN
# 2298                                                NaN
# 2299                                                NaN
# 2300                                                NaN
#
#                 BOARD OF DIRECTORS           Employees
# 0                              NaN                 NaN
# 1     Greame Sewell, Negar Towfigh                 NaN
# 2                              NaN                 NaN
# 3     David Mersky, Booker T Evans  1 as of 06/01/2024
# 4     Joseph Vitale, Vincent Fazio                 Nan
# ...                            ...                 ...
# 2296                           NaN                 NaN
# 2297                           NaN                 NaN
# 2298                           NaN                 NaN
# 2299            Winston Yau-lai LO                 NaN
# 2300            Winston Yau-lai LO                 NaN
#
# [2291 rows x 16 columns]

# %%
df.tail(30)
# Out:
#     Company Symbol   Market Cap Authorized Shares Outstanding Shares  \
# 250           IFHI   71,011,287         4,000,000          2,323,759
# 251           INBC   95,062,364        70,000,000         11,772,429
# 252           ISBA  139,809,335        15,000,000          7,476,435
# 253           JBTC   59,625,552         6,000,000          2,433,696
# 254           JDVB   75,578,712        10,000,000          3,435,396
# 255           JUVF   61,291,454        20,000,000          5,003,384
# 256           KISB   88,894,710         8,000,000          2,963,157
# 257           KTHN   66,482,805        20,000,000          3,194,369
# 258           LBNW    8,168,782        50,000,000          1,650,259
# 259           LFGP   48,050,602        11,000,000          3,525,356
# 260           LUMB   42,803,105         5,000,000          3,230,423
# 261           LYBC  132,823,823        15,000,000          3,374,589
# 262           MBLU  190,785,389        50,000,000         10,605,080
# 263           MCBI  103,258,768        20,000,000          6,373,998
# 264           MNAT  111,752,779         6,000,000          4,380,744
# 265           MNMB   60,530,379         5,000,000          1,330,338
# 266           MSVB   41,400,310        30,000,000          2,885,039
# 267           MVLY   45,767,618        10,000,000          3,328,554
# 268           NASB  245,810,234        20,000,000          7,392,789
# 269           OAKC  133,313,229        10,000,000          4,937,527
# 270           OFED   74,790,032       100,000,000          5,838,410
# 271           OSBK   37,131,154         1,500,000          1,045,948
# 272           OTTW   30,338,665       100,000,000          2,545,190
# 273           PBAM  200,521,758        20,000,000          5,734,518
# 274           PBNC  117,981,261        10,000,000          2,923,941
# 275           PFBX   74,586,976        15,000,000          4,661,686
# 276           PFLC   99,738,125        25,000,000         10,335,557
# 277           PMHG   74,605,997         9,000,000          3,293,863
# 278           PPBN   61,457,509         3,000,000          2,214,685
# 279           PSBQ   86,025,728        18,000,000          4,223,158
#
#     Par Value SEC Filings                                            Address  \
# 250      1.00         NaN  8450 Falls of Neuse Rd, Suite 202 Raleigh, NC ...
# 251      0.01         NaN        3615 Delgany St Suite 1010 Denver, CO 80216
# 252       NaN         NaN              401 N. Main St Mt. Pleasant, MI 48858
# 253      2.00         NaN  2 West Market Street PO Box 717 Jonestown, PA ...
# 254      6.25         NaN                  1611 Elton Rd. Jennings, LA 70546
# 255      1.00         NaN      Bridge and Main Streets Mifflintown, PA 17059
# 256      0.50         NaN  4255 East Main Street (Rt. 655) P.O. Box 917 B...
# 257      1.00         NaN     20 Katahdin Lane P.O. Box 36 Houlton, ME 04730
# 258      1.00         NaN             20150 Seventh Ave NE Poulsbo, WA 98370
# 259      0.33         NaN   66 Benning Street Suite 5 West Lebanon, NH 03784
# 260      2.00         NaN               403 E. 3rd Street Pembroke, NC 28372
# 261      0.50         NaN               399 Exchange Street Geneva, NY 14456
# 262      1.00         NaN      300 Bellevue Ave. PO Box 520 Dublin, GA 31040
# 263      0.01         NaN             6101 Kingston Pike Knoxville, TN 37919
# 264      0.01         NaN        6316 S. Western Ave. Chicago, IL 60636-2491
# 265      2.50         NaN        3118 Pascagoula Street Pascagoula, MS 39567
# 266      0.01         NaN             300 North Water Street Salem, IN 47167
# 267       NaN         NaN            9116 Sunland Blvd. Sun Valley, CA 91352
# 268      0.15         NaN         12498 South 71 Highway Grandview, MO 64030
# 269      5.00         NaN  850 Shades Creek Pkwy, St 200 Mountain Brook, ...
# 270      0.01         NaN      201 East North Second Street Seneca, SC 29678
# 271      2.00         NaN           41 N. Main Street Watkinsville, GA 30677
# 272      1.00         NaN                925 LaSalle Street Ottawa, IL 61350
# 273       NaN         NaN   9404 Genesee Avenue Suite 100 La Jolla, CA 90237
# 274      1.00         NaN  PO Box 7727 450 North Winstead Avenue Rocky Mo...
# 275      1.00         NaN  Lameuse and Howard Avenues 152 Lameuse Street ...
# 276      1.00         NaN              1216 Skyview Drive Aberdeen, WA 98520
# 277      0.01         NaN         1471 Timberlane Road Tallahassee, FL 32312
# 278      3.00         NaN     622 Broad Street PO Box 29 Altavista, VA 24517
# 279       NaN         NaN               1905 Stewart Avenue Wausau, WI 54401
#
#                         Website              Phone  \
# 250              www.ifhinc.com       919-302-2277
# 251              www.inbank.com    +1 720-552-8325
# 252        www.isabellabank.com      +1 9897796237
# 253                www.jbt.bank    +1 717-865-4246
# 254              www.jdbank.com    +1 337-824-1422
# 255           www.jvbonline.com       855-582-5101
# 256            www.kishbank.com    +1 814-861-4747
# 257       www.katahdintrust.com    +1 207-521-0455
# 258       www.libertybanknw.com    +1 360-779-4567
# 259         www.ledyardbank.com       603-643-2244
# 260  www.lumbeeguarantybank.com    +1 910-521-9707
# 261         www.bankwithlnb.com    +1 315-946-4871
# 262             www.morris.bank    +1 478-272-5202
# 263                 www.mcb.com    +1 865-694-5731
# 264      www.emarquettebank.com    +1 708-364-9019
# 265           www.mandmbank.com    +1 228-762-3311
# 266        www.mid-southern.com  +1 (812) 883-2639
# 267   www.missionvalleybank.com    +1 818-394-2300
# 268                www.nasb.com    +1 816-765-2200
# 269            www.oakworth.com    +1 205-263-4700
# 270       www.oconeefederal.com       864-882-2765
# 271     www.oconeestatebank.com    +1 706-769-6611
# 272              www.myosb.bank      +1 8154332525
# 273         www.calprivate.bank    +1 858-875-6900
# 274               www.pbknc.com    +1 252-443-9477
# 275          www.thepeoples.com      +1 2284355511
# 276    www.bankofthepacific.com    +1 360-537-4060
# 277   www.primemeridianbank.com    +1 850-907-2300
# 278            www.1stnatbk.com    +1 434-369-3000
# 279         www.bankpeoples.com    +1 715-842-2191
#
#                                     Email Audited Financials Latest Report  \
# 250                      steve@ifhinc.com                NaN           NaN
# 251         investor.relations@inbank.com                NaN           NaN
# 252  shareholderservices@isabellabank.com                NaN           NaN
# 253                     investor@jbt.bank                NaN           NaN
# 254                       info@jdbank.com                NaN           NaN
# 255                 jvbonline@banking.com                NaN           NaN
# 256                contactus@kishbank.com                NaN           NaN
# 257                info@katahdintrust.com                NaN           NaN
# 258                info@libertybanknw.com                NaN           NaN
# 259             contactus@ledyardbank.com                NaN           NaN
# 260     kylechavis@lumbeeguarantybank.com                NaN           NaN
# 261                csnook@bankwithlnb.com                NaN           NaN
# 262                 investors@morris.bank                NaN           NaN
# 263                            ir@mcb.com                NaN           NaN
# 264              phunt@emarquettebank.com                NaN           NaN
# 265          jackie.skelton@mandmbank.com                NaN           NaN
# 266            bank.info@mid-southern.com                NaN           NaN
# 267            info@missionvalleybank.com                NaN           NaN
# 268           investor.relations@nasb.com                NaN           NaN
# 269                solutions@oakworth.com                NaN           NaN
# 270                bank@oconeefederal.com                NaN           NaN
# 271              info@oconeestatebank.com                NaN           NaN
# 272                    chepner@myosb.bank                NaN           NaN
# 273     investorrelations@calprivate.bank                NaN           NaN
# 274           investorrelations@pbknc.com                NaN           NaN
# 275      investorrelations@thepeoples.com                NaN           NaN
# 276          ctucker@bankofthepacific.com                NaN           NaN
# 277            info@primemeridianbank.com                NaN           NaN
# 278              bryanlemley@1stnatbk.com                NaN           NaN
# 279     investorrelations@bankpeoples.com                NaN           NaN
#
#     Fiscal Year End                                   Company Officers  \
# 250             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 251             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 252             NaN  Reporting Status (U.S. Reporting: SEC Reportin...
# 253             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 254             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 255             NaN  Reporting Status (U.S. Reporting: SEC Reportin...
# 256             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 257             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 258             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 259             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 260             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 261             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 262             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 263             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 264             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 265             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 266             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 267             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 268             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 269             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 270             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 271             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 272             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 273             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 274             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 275             NaN  Reporting Status (U.S. Reporting: SEC Reportin...
# 276             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 277             NaN  Reporting Status (U.S. Reporting: SEC Reportin...
# 278             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
# 279             NaN  Reporting Status (U.S. Reporting: Bank/Thrift)...
#
#                                     BOARD OF DIRECTORS Employees
# 250  Marc H. McConnell, Melissa D. Marsal, Steven E...       Nan
# 251  Edward Guy Francis, Eric Albert Donnelly, Bo S...       Nan
# 252  Jerome E. Schwind, Neil McDonnell, William M. ...       Nan
# 253  Troy A. Peters, Edward L. Anspach, Edward T. M...       Nan
# 254  Bruce W. Elder, Paul E. Brummett II, Jimmy LeB...       Nan
# 255    Marcie A. Barber, Michael Wolf, Cortney Wilbert       Nan
# 256  Gregory T. Hayes, Mark Cvrkel, Allan F. Bills,...       Nan
# 257  Jon J. Prescott, Matt Nightingale, Angela Butl...       Nan
# 258          Richard Darrow, Rhonda Morris, Jeremy Key       Nan
# 259  Josephine Moran, Peteris Sprudzs, Sara V. Blak...       Nan
# 260  Kyle R. Chavis, Bryan K. Maynor, James W. Gore...       Nan
# 261  Case Alan Marshall, Chad J. Proper, Carol A. S...       Nan
# 262  Spencer Neil Mullis, Leonard Blount, Christoph...       Nan
# 263  Michael L. Hatcher, William E. Edwards III, Re...       Nan
# 264     Paul M. McCarthy, George Moncada, Patrick Hunt       Nan
# 265  Clayton Legear, Casey Barnett Hill, Jackie Ske...       Nan
# 266  Alexander G. Babey, Robert W. DeRossett, Erica...       Nan
# 267  Tamara Gurney, Anthony Chuan, Lisa Mora, Micha...       Nan
# 268       Thomas Wagers, Rhonda G. Nyhus, Scott Gootee       Nan
# 269  Scott B. Reed, David M. Driscoll, Sam A. Scali...       Nan
# 270  Curt Evatt, David Stafford, John Hobbs, Todd L...       Nan
# 271  T. Neil Stevens, James R. McLemore, Pamela J L...       Nan
# 272  Craig M. Hepner, Marc N. Kingry, Laurie Duffel...       Nan
# 273                       Rick A. Sowers, Cory Stewart       Nan
# 274                   Ted E. Whitehurst, David E. Keul       Nan
# 275  Chevis C. Swetman, Leslie B Fulton, A. Wes Ful...       Nan
# 276  Denise Portmann, Terri McKinnis, Carla F Tucke...       Nan
# 277  Sammie D. Dixon, Jr., Clint F. Weber, Susan Pa...       Nan
# 278                  Aubrey H. Hall, III, Bryan Lemley       Nan
# 279  Scott M. Cattanach, Jessica M Barnes, Patrick ...       Nan
